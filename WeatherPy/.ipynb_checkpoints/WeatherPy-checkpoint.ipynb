# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
# output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %%
# # Creating a manageable v small list bc ...scared
# small_list = cities[:15]
# small_list

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
unit = "imperial"
city_with_data = []

lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

counter = 0


for city in cities:
    
    query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit
    city_response = requests.get(query_url)
    city_json = city_response.json()
    
    try:
        city_data = city_json
        lat.append(city_data['coord']['lat'])
        lng.append(city_data['coord']['lon'])
        max_temp.append(city_data['main']['temp_max'])
        humidity.append(city_data['main']['humidity'])
        cloudiness.append(city_data['clouds']['all'])
        wind_speed.append(city_data['wind']['speed'])
        country.append(city_data['sys']['country'])
        date.append(city_data['dt'])
        city_with_data.append(city_data['name'])
        
        counter += 1
        if counter == 51:
            time.sleep(60)
            print(f'Zzzz...Counter Reset')
            counter = 1
    
        print(f"This is pull {counter} for {city} data.")
    
    except KeyError:
        print(f"Oops, no data for {city}.")
# Out:
# This is pull 1 for fairbanks data.
# This is pull 2 for atuona data.
# This is pull 3 for jamestown data.
# This is pull 4 for port alfred data.
# This is pull 5 for auki data.
# This is pull 6 for thompson data.
# This is pull 7 for petropavlovsk-kamchatskiy data.
# This is pull 8 for mataura data.
# This is pull 9 for rikitea data.
# This is pull 10 for ascension data.
# This is pull 11 for kaitangata data.
# This is pull 12 for isangel data.
# This is pull 13 for butaritari data.
# Oops, no data for dera din panah.
# This is pull 14 for coquimbo data.
# This is pull 15 for gornopravdinsk data.
# This is pull 16 for tasiilaq data.
# This is pull 17 for mbekenyera data.
# This is pull 18 for ugoofaaru data.
# This is pull 19 for chuy data.
# Oops, no data for umzimvubu.
# This is pull 20 for cabo san lucas data.
# This is pull 21 for coihaique data.
# This is pull 22 for rochegda data.
# This is pull 23 for saldanha data.
# This is pull 24 for vaini data.
# This is pull 25 for margate data.
# This is pull 26 for east london data.
# This is pull 27 for jiazi data.
# This is pull 28 for ternate data.
# This is pull 29 for pevek data.
# This is pull 30 for barrow data.
# Oops, no data for galiwinku.
# This is pull 31 for bredasdorp data.
# This is pull 32 for kundiawa data.
# This is pull 33 for cabra data.
# This is pull 34 for hobart data.
# This is pull 35 for carlyle data.
# This is pull 36 for yellowknife data.
# This is pull 37 for saint-georges data.
# This is pull 38 for ushuaia data.
# Oops, no data for saleaula.
# This is pull 39 for alofi data.
# This is pull 40 for busselton data.
# This is pull 41 for victoria data.
# This is pull 42 for kapaa data.
# This is pull 43 for blackfoot data.
# This is pull 44 for bluff data.
# This is pull 45 for ixtapa data.
# This is pull 46 for kelapa sawit data.
# This is pull 47 for payson data.
# This is pull 48 for ponta do sol data.
# Oops, no data for barentsburg.
# Oops, no data for illoqqortoormiut.
# This is pull 49 for bandundu data.
# This is pull 50 for saskylakh data.
# Zzzz...Counter Reset
# This is pull 1 for puerto ayora data.
# This is pull 2 for srednekolymsk data.
# This is pull 3 for watertown data.
# This is pull 4 for tuatapere data.
# This is pull 5 for avarua data.
# This is pull 6 for necochea data.
# This is pull 7 for gilgit data.
# This is pull 8 for houma data.
# This is pull 9 for anloga data.
# This is pull 10 for kongolo data.
# This is pull 11 for putina data.
# This is pull 12 for pangody data.
# Oops, no data for aflu.
# This is pull 13 for ribeira grande data.
# This is pull 14 for villarrica data.
# This is pull 15 for mukono data.
# This is pull 16 for diamantino data.
# This is pull 17 for sibolga data.
# This is pull 18 for leon data.
# This is pull 19 for cape town data.
# This is pull 20 for carthage data.
# This is pull 21 for nurota data.
# This is pull 22 for high level data.
# This is pull 23 for bireun data.
# This is pull 24 for nantucket data.
# This is pull 25 for saint-philippe data.
# Oops, no data for belushya guba.
# This is pull 26 for esperance data.
# This is pull 27 for new norfolk data.
# This is pull 28 for saint-francois data.
# Oops, no data for grand river south east.
# This is pull 29 for kedrovoye data.
# This is pull 30 for punta arenas data.
# This is pull 31 for souillac data.
# This is pull 32 for mahebourg data.
# This is pull 33 for khanu woralaksaburi data.
# This is pull 34 for cayenne data.
# Oops, no data for mys shmidta.
# This is pull 35 for saint anthony data.
# This is pull 36 for beringovskiy data.
# Oops, no data for palabuhanratu.
# This is pull 37 for portalegre data.
# This is pull 38 for upernavik data.
# This is pull 39 for kyaikto data.
# This is pull 40 for korla data.
# This is pull 41 for albany data.
# This is pull 42 for hofn data.
# This is pull 43 for komsomolskiy data.
# This is pull 44 for pangnirtung data.
# This is pull 45 for kodiak data.
# This is pull 46 for lebu data.
# This is pull 47 for paamiut data.
# This is pull 48 for marsa matruh data.
# This is pull 49 for lakselv data.
# This is pull 50 for medicine hat data.
# Zzzz...Counter Reset
# This is pull 1 for cherskiy data.
# This is pull 2 for rogers data.
# Oops, no data for attawapiskat.
# This is pull 3 for clyde river data.
# This is pull 4 for galle data.
# This is pull 5 for georgetown data.
# This is pull 6 for lagoa data.
# This is pull 7 for bethel data.
# This is pull 8 for chichester data.
# This is pull 9 for qaanaaq data.
# Oops, no data for louisbourg.
# This is pull 10 for hilo data.
# This is pull 11 for lompoc data.
# This is pull 12 for cosambesti data.
# This is pull 13 for katsuura data.
# Oops, no data for taolanaro.
# This is pull 14 for tilichiki data.
# This is pull 15 for nowy dwor gdanski data.
# Oops, no data for amderma.
# This is pull 16 for birjand data.
# This is pull 17 for pinotepa nacional data.
# This is pull 18 for luderitz data.
# This is pull 19 for kerrville data.
# This is pull 20 for muisne data.
# Oops, no data for samusu.
# This is pull 21 for zlobin data.
# This is pull 22 for macusani data.
# This is pull 23 for westport data.
# This is pull 24 for chokurdakh data.
# This is pull 25 for kencong data.
# This is pull 26 for ornskoldsvik data.
# This is pull 27 for mar del plata data.
# This is pull 28 for maniitsoq data.
# This is pull 29 for kavieng data.
# This is pull 30 for hermanus data.
# This is pull 31 for nago data.
# This is pull 32 for kiama data.
# This is pull 33 for college data.
# This is pull 34 for aksehir data.
# This is pull 35 for antofagasta data.
# This is pull 36 for carroll data.
# This is pull 37 for mgandu data.
# This is pull 38 for fortuna data.
# This is pull 39 for taoudenni data.
# This is pull 40 for burgeo data.
# This is pull 41 for doka data.
# This is pull 42 for san pedro data.
# This is pull 43 for berlevag data.
# This is pull 44 for carnarvon data.
# This is pull 45 for rocha data.
# This is pull 46 for zeya data.
# This is pull 47 for tuktoyaktuk data.
# This is pull 48 for carson city data.
# This is pull 49 for canton data.
# This is pull 50 for pingliang data.
# Zzzz...Counter Reset
# This is pull 1 for catia la mar data.
# This is pull 2 for deputatskiy data.
# This is pull 3 for san lorenzo data.
# Oops, no data for tsihombe.
# This is pull 4 for chicama data.
# This is pull 5 for tiksi data.
# This is pull 6 for flin flon data.
# This is pull 7 for aasiaat data.
# This is pull 8 for san ramon de la nueva oran data.
# This is pull 9 for castro data.
# This is pull 10 for almaznyy data.
# This is pull 11 for abbeville data.
# This is pull 12 for porto santo data.
# This is pull 13 for cap malheureux data.
# This is pull 14 for shimoda data.
# This is pull 15 for arraial do cabo data.
# This is pull 16 for kaabong data.
# This is pull 17 for portland data.
# This is pull 18 for carepa data.
# This is pull 19 for kingston data.
# This is pull 20 for zhoucheng data.
# This is pull 21 for ust-kuyga data.
# This is pull 22 for lakes entrance data.
# This is pull 23 for severo-kurilsk data.
# This is pull 24 for puerto colombia data.
# This is pull 25 for dawlatabad data.
# This is pull 26 for port hedland data.
# Oops, no data for kamenskoye.
# This is pull 27 for takoradi data.
# This is pull 28 for port macquarie data.
# This is pull 29 for yuzhno-sukhokumsk data.
# This is pull 30 for hambantota data.
# This is pull 31 for boende data.
# This is pull 32 for oga data.
# Oops, no data for koyilandi.
# This is pull 33 for ulaangom data.
# This is pull 34 for juquitiba data.
# This is pull 35 for san cristobal data.
# This is pull 36 for kruisfontein data.
# This is pull 37 for grindavik data.
# This is pull 38 for arroyo grande data.
# This is pull 39 for sao filipe data.
# This is pull 40 for mahibadhoo data.
# This is pull 41 for bambous virieux data.
# This is pull 42 for anqing data.
# This is pull 43 for price data.
# This is pull 44 for saint george data.
# This is pull 45 for khatanga data.
# This is pull 46 for san nicolas data.
# This is pull 47 for shingu data.
# This is pull 48 for port-gentil data.
# This is pull 49 for paka data.
# This is pull 50 for te anau data.
# Zzzz...Counter Reset
# This is pull 1 for lorengau data.
# This is pull 2 for nagorsk data.
# This is pull 3 for faanui data.
# This is pull 4 for stornoway data.
# This is pull 5 for hutchinson data.
# This is pull 6 for hervey bay data.
# This is pull 7 for san carlos de bariloche data.
# This is pull 8 for praia data.
# This is pull 9 for provideniya data.
# Oops, no data for nizhneyansk.
# This is pull 10 for klaksvik data.
# This is pull 11 for ilulissat data.
# This is pull 12 for soyo data.
# This is pull 13 for yar-sale data.
# This is pull 14 for saint-augustin data.
# This is pull 15 for gamba data.
# This is pull 16 for kirakira data.
# This is pull 17 for aruppukkottai data.
# This is pull 18 for longonjo data.
# This is pull 19 for grand gaube data.
# This is pull 20 for mitsamiouli data.
# This is pull 21 for sungai besar data.
# This is pull 22 for vangaindrano data.
# This is pull 23 for trinidad data.
# This is pull 24 for athabasca data.
# This is pull 25 for calama data.
# This is pull 26 for altea data.
# This is pull 27 for tazovskiy data.
# This is pull 28 for san patricio data.
# This is pull 29 for muscat data.
# This is pull 30 for ayan data.
# This is pull 31 for vila franca do campo data.
# This is pull 32 for ostrovnoy data.
# This is pull 33 for albacete data.
# This is pull 34 for mutis data.
# This is pull 35 for corowa data.
# This is pull 36 for abaza data.
# This is pull 37 for winslow data.
# This is pull 38 for hithadhoo data.
# This is pull 39 for champerico data.
# This is pull 40 for gladstone data.
# This is pull 41 for kushima data.
# This is pull 42 for kerrobert data.
# This is pull 43 for minuri data.
# This is pull 44 for dikson data.
# Oops, no data for karaul.
# This is pull 45 for vanimo data.
# This is pull 46 for sitka data.
# This is pull 47 for togur data.
# This is pull 48 for neijiang data.
# This is pull 49 for demyansk data.
# This is pull 50 for sobolevo data.
# Zzzz...Counter Reset
# This is pull 1 for bengkulu data.
# This is pull 2 for neiafu data.
# This is pull 3 for chingola data.
# This is pull 4 for olafsvik data.
# This is pull 5 for marica data.
# This is pull 6 for bajil data.
# This is pull 7 for rovaniemi data.
# This is pull 8 for sovetskiy data.
# This is pull 9 for pacific grove data.
# This is pull 10 for port elizabeth data.
# This is pull 11 for waldkraiburg data.
# This is pull 12 for barra do garcas data.
# This is pull 13 for hasaki data.
# This is pull 14 for atambua data.
# This is pull 15 for kahului data.
# This is pull 16 for poum data.
# This is pull 17 for xambioa data.
# This is pull 18 for norman wells data.
# This is pull 19 for leningradskiy data.
# This is pull 20 for lake charles data.
# This is pull 21 for tortoli data.
# This is pull 22 for piacabucu data.
# This is pull 23 for alihe data.
# This is pull 24 for saint-joseph data.
# This is pull 25 for dakar data.
# This is pull 26 for wenling data.
# This is pull 27 for vao data.
# This is pull 28 for nikolskoye data.
# This is pull 29 for roald data.
# This is pull 30 for fort nelson data.
# This is pull 31 for sinnamary data.
# This is pull 32 for los llanos de aridane data.
# This is pull 33 for yuxia data.
# This is pull 34 for ilhabela data.
# This is pull 35 for port blair data.
# This is pull 36 for touros data.
# This is pull 37 for alice springs data.
# This is pull 38 for lasa data.
# This is pull 39 for wellsford data.
# This is pull 40 for codrington data.
# This is pull 41 for fujin data.
# This is pull 42 for davila data.
# This is pull 43 for caravelas data.
# This is pull 44 for tripoli data.
# This is pull 45 for ancud data.
# This is pull 46 for maple creek data.
# This is pull 47 for huarmey data.
# Oops, no data for doctor pedro p. pena.
# This is pull 48 for cartagena data.
# This is pull 49 for vila velha data.
# This is pull 50 for sayyan data.
# Oops, no data for wulanhaote.
# Zzzz...Counter Reset
# This is pull 1 for noceto data.
# This is pull 2 for owando data.
# This is pull 3 for tucupita data.
# This is pull 4 for aksu data.
# This is pull 5 for namatanai data.
# This is pull 6 for luena data.
# This is pull 7 for linxia data.
# This is pull 8 for itarema data.
# Oops, no data for bolungarvik.
# This is pull 9 for sisimiut data.
# This is pull 10 for huangchuan data.
# This is pull 11 for energetik data.
# This is pull 12 for san quintin data.
# This is pull 13 for qaqortoq data.
# This is pull 14 for ampanihy data.
# Oops, no data for bargal.
# This is pull 15 for iqaluit data.
# Oops, no data for vaitupu.
# This is pull 16 for nome data.
# This is pull 17 for robertsport data.
# This is pull 18 for tautira data.
# This is pull 19 for bhan data.
# This is pull 20 for abu kamal data.
# This is pull 21 for batagay data.
# This is pull 22 for landerneau data.
# This is pull 23 for west mifflin data.
# This is pull 24 for pingshan data.
# This is pull 25 for ormara data.
# This is pull 26 for harnosand data.
# This is pull 27 for uribia data.
# This is pull 28 for san jose data.
# This is pull 29 for hamilton data.
# This is pull 30 for yining data.
# This is pull 31 for santa fe data.
# This is pull 32 for avera data.
# This is pull 33 for airai data.
# This is pull 34 for pisco data.
# This is pull 35 for ranong data.
# This is pull 36 for horta data.
# Oops, no data for tir pol.
# Oops, no data for tumannyy.
# This is pull 37 for ambagarh chauki data.
# This is pull 38 for borogontsy data.
# This is pull 39 for wanning data.
# This is pull 40 for tonota data.
# This is pull 41 for porto walter data.
# This is pull 42 for half moon bay data.
# This is pull 43 for shama data.
# This is pull 44 for manaure data.
# This is pull 45 for hellvik data.
# This is pull 46 for bagotville data.
# This is pull 47 for darhan data.
# This is pull 48 for korhogo data.
# This is pull 49 for severodvinsk data.
# This is pull 50 for carmo do rio claro data.
# Zzzz...Counter Reset
# This is pull 1 for jimeta data.
# This is pull 2 for kilrush data.
# This is pull 3 for mount isa data.
# This is pull 4 for chernyshevskiy data.
# Oops, no data for toliary.
# This is pull 5 for olinda data.
# This is pull 6 for camapua data.
# This is pull 7 for kaele data.
# This is pull 8 for longyearbyen data.
# This is pull 9 for aksarka data.
# This is pull 10 for mengcheng data.
# This is pull 11 for bose data.
# This is pull 12 for marsh harbour data.
# This is pull 13 for carolina data.
# This is pull 14 for beloha data.
# This is pull 15 for grootfontein data.
# This is pull 16 for broome data.
# This is pull 17 for zaraza data.
# This is pull 18 for bondo data.
# This is pull 19 for dingle data.
# This is pull 20 for kenai data.
# This is pull 21 for mendoza data.
# This is pull 22 for kakching data.
# This is pull 23 for varna data.
# This is pull 24 for lata data.
# This is pull 25 for nichinan data.
# This is pull 26 for evensk data.
# This is pull 27 for la palma data.
# This is pull 28 for cairns data.
# This is pull 29 for daugavpils data.
# This is pull 30 for sola data.
# This is pull 31 for chernihiv data.
# This is pull 32 for gwadar data.
# This is pull 33 for yerbogachen data.
# This is pull 34 for geraldton data.
# Oops, no data for saryshagan.
# This is pull 35 for santa cruz de la palma data.
# This is pull 36 for biak data.
# This is pull 37 for sovetskaya data.
# This is pull 38 for khani data.
# This is pull 39 for aktau data.
# This is pull 40 for namibe data.
# This is pull 41 for xuddur data.
# This is pull 42 for oranjemund data.
# This is pull 43 for xai-xai data.
# Oops, no data for khonuu.
# This is pull 44 for longyan data.
# This is pull 45 for manadhoo data.
# This is pull 46 for dunmore town data.
# Oops, no data for sentyabrskiy.
# This is pull 47 for bathsheba data.
# Oops, no data for mirina.
# This is pull 48 for tinskoy data.
# This is pull 49 for marsabit data.
# This is pull 50 for nhulunbuy data.
# Zzzz...Counter Reset
# This is pull 1 for magistralnyy data.
# This is pull 2 for maragogi data.
# This is pull 3 for fukue data.
# This is pull 4 for dzilam gonzalez data.
# This is pull 5 for nishihara data.
# This is pull 6 for tuy hoa data.
# This is pull 7 for aklavik data.
# This is pull 8 for pochutla data.
# This is pull 9 for chulym data.
# This is pull 10 for paita data.
# This is pull 11 for ostersund data.
# This is pull 12 for iracoubo data.
# This is pull 13 for tandil data.
# This is pull 14 for naze data.
# Oops, no data for azimur.
# Oops, no data for mudyuga.
# This is pull 15 for wembley data.
# This is pull 16 for dinard data.
# This is pull 17 for senador guiomard data.
# Oops, no data for ijaki.
# This is pull 18 for santa cruz del norte data.
# This is pull 19 for alyangula data.
# This is pull 20 for kingsville data.
# This is pull 21 for hakkari data.
# Oops, no data for mutsamudu.
# This is pull 22 for vanavara data.
# This is pull 23 for bud data.
# This is pull 24 for porto novo data.
# This is pull 25 for thyboron data.
# This is pull 26 for talara data.
# This is pull 27 for port hardy data.
# This is pull 28 for nanortalik data.
# This is pull 29 for tual data.
# This is pull 30 for acapulco data.
# This is pull 31 for chimore data.
# This is pull 32 for beisfjord data.
# Oops, no data for lolua.
# This is pull 33 for the valley data.
# This is pull 34 for barranca data.
# This is pull 35 for vung tau data.
# This is pull 36 for salamanca data.
# This is pull 37 for dubbo data.
# This is pull 38 for tsumeb data.
# This is pull 39 for bubaque data.
# This is pull 40 for charlestown data.
# This is pull 41 for pacifica data.
# This is pull 42 for husavik data.
# This is pull 43 for nalut data.
# This is pull 44 for bandarbeyla data.
# This is pull 45 for zyryanka data.
# This is pull 46 for boyolangu data.
# This is pull 47 for labuhan data.
# This is pull 48 for haines junction data.
# This is pull 49 for sioux lookout data.
# This is pull 50 for havelock data.
# Zzzz...Counter Reset
# This is pull 1 for mount gambier data.
# This is pull 2 for amga data.
# This is pull 3 for ballina data.
# This is pull 4 for mehamn data.
# This is pull 5 for warrnambool data.
# This is pull 6 for campoverde data.
# This is pull 7 for cidreira data.
# This is pull 8 for ahipara data.
# This is pull 9 for manuk mangkaw data.
# This is pull 10 for torbay data.
# This is pull 11 for mujiayingzi data.
# This is pull 12 for leninsk data.
# This is pull 13 for esmeralda data.
# This is pull 14 for sfantu gheorghe data.
# This is pull 15 for srivardhan data.
# This is pull 16 for la asuncion data.
# This is pull 17 for karratha data.
# This is pull 18 for salalah data.
# This is pull 19 for bawku data.
# This is pull 20 for khasan data.
# This is pull 21 for sorland data.
# This is pull 22 for rawson data.
# This is pull 23 for nouadhibou data.
# This is pull 24 for shubarkuduk data.
# This is pull 25 for lavrentiya data.
# This is pull 26 for setermoen data.
# This is pull 27 for sao joao da barra data.
# This is pull 28 for gat data.
# This is pull 29 for ulmu data.
# Oops, no data for rawannawi.
# This is pull 30 for seminole data.
# This is pull 31 for eyl data.
# This is pull 32 for ahuimanu data.
# This is pull 33 for morondava data.
# Oops, no data for meyungs.
# This is pull 34 for villamontes data.
# This is pull 35 for borzna data.
# Oops, no data for bur gabo.
# This is pull 36 for vikhorevka data.
# This is pull 37 for bourail data.
# This is pull 38 for banjar data.
# This is pull 39 for guilin data.
# This is pull 40 for troitsko-pechorsk data.
# This is pull 41 for imeni morozova data.
# This is pull 42 for kavaratti data.
# This is pull 43 for tateyama data.
# This is pull 44 for starovelichkovskaya data.
# Oops, no data for solsvik.
# This is pull 45 for tibati data.
# This is pull 46 for acarau data.
# This is pull 47 for ust-nera data.
# This is pull 48 for axim data.
# This is pull 49 for palmer data.
# This is pull 50 for racine data.
# Zzzz...Counter Reset
# This is pull 1 for kyabe data.
# This is pull 2 for aswan data.
# This is pull 3 for doha data.
# This is pull 4 for orshanka data.
# This is pull 5 for emba data.
# This is pull 6 for altopascio data.
# This is pull 7 for yanam data.
# This is pull 8 for bundaberg data.
# This is pull 9 for lakheri data.
# This is pull 10 for pingxiang data.
# This is pull 11 for ola data.
# Oops, no data for strazica.
# This is pull 12 for kenitra data.
# This is pull 13 for vardo data.
# This is pull 14 for dingzhou data.
# This is pull 15 for lunenburg data.
# This is pull 16 for altamont data.
# Oops, no data for haibowan.
# This is pull 17 for bam data.
# This is pull 18 for vredendal data.
# This is pull 19 for antalaha data.
# This is pull 20 for paso de patria data.
# This is pull 21 for marovoay data.
# This is pull 22 for juneau data.
# This is pull 23 for alexandria data.
# Oops, no data for yirol.
# This is pull 24 for cururupu data.
# This is pull 25 for alegrete data.
# This is pull 26 for duvan data.
# Oops, no data for abu jubayhah.
# This is pull 27 for atar data.
# This is pull 28 for vinh data.
# This is pull 29 for narsaq data.
# This is pull 30 for vostok data.
# This is pull 31 for hailey data.
# This is pull 32 for wajima data.
# This is pull 33 for arlit data.
# This is pull 34 for kaiwaka data.
# This is pull 35 for saint john data.
# This is pull 36 for swift current data.
# This is pull 37 for sidi ali data.
# This is pull 38 for inuvik data.
# This is pull 39 for bitung data.
# This is pull 40 for tadine data.
# This is pull 41 for hami data.
# This is pull 42 for novosil data.
# This is pull 43 for mayo data.
# This is pull 44 for bushehr data.
# This is pull 45 for erenhot data.
# This is pull 46 for sambava data.
# This is pull 47 for matamoros data.
# This is pull 48 for jiaojiang data.
# This is pull 49 for roswell data.
# This is pull 50 for mrakovo data.
# Zzzz...Counter Reset
# This is pull 1 for zhigansk data.
# Oops, no data for marcona.

# %%
city_dict = {
    "city" : city_with_data,
    "lat" : lat,
    "lng" : lng,
    "max temp" : max_temp,
    "humidity" : humidity,
    "cloudiness" : cloudiness,
    "wind speed" : wind_speed,
    "country id" : country,
    "date" : date
}

city_df = pd.DataFrame(city_dict)
city_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a8fc9fbc6f3d> in <module>
#       1 city_dict = {
# ----> 2     "city" : city_with_data,
#       3     "lat" : lat,
#       4     "lng" : lng,
#       5     "max temp" : max_temp,
#
# NameError: name 'city_with_data' is not defined

# %%
city_df.to_csv('output_data/weatherpy_data.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-435005cbb342> in <module>
# ----> 1 city_df.to_csv('output_data/weatherpy_data.csv', index = False)
#
# NameError: name 'city_df' is not defined

# %%
# city_df.info()

# %%
city_summary = city_df.describe()

city_summary
# Out:
#               lat         lng    max temp    humidity  cloudiness  wind speed  \
# count  551.000000  551.000000  551.000000  551.000000  551.000000  551.000000
# mean    20.357747   16.514038   50.883267   73.355717   61.509982    8.272541
# std     33.204363   91.594928   30.393913   20.490986   39.905700    6.043219
# min    -54.800000 -175.200000  -42.030000   11.000000    0.000000    0.000000
# 25%     -8.229300  -65.117800   30.260000   61.000000   20.000000    3.850000
# 50%     25.281900   18.501200   61.840000   77.000000   75.000000    6.910000
# 75%     47.438350  102.389850   76.530000   89.000000  100.000000   11.070000
# max     78.218600  179.316700   91.450000  100.000000  100.000000   40.290000
#
#                date
# count  5.510000e+02
# mean   1.643405e+09
# std    2.547126e+02
# min    1.643404e+09
# 25%    1.643405e+09
# 50%    1.643405e+09
# 75%    1.643405e+09
# max    1.643405e+09

# %%
over_hun = city_df.loc[city_df["humidity"] > 100]
city_df = city_df.loc[city_df["humidity"] != 100]

# %%
plt.scatter(city_df["lat"], city_df["max temp"], alpha = 0.5, edgecolor = "black")
plt.grid()

plt.title('City Latitude v. Max Temperture ')
plt.xlabel("Latitude")
plt.ylabel("Max Temperture (F)")

plt.savefig("output_data/city_lat_temp.png")

# %%
plt.scatter(city_df["lat"], city_df["humidity"], alpha = 0.5, edgecolor = "black")
plt.grid()

plt.title('City Latitude v. Humidity ')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("output_data/city_lat_humidity.png")

# %%
plt.scatter(city_df["lat"], city_df["cloudiness"], alpha = 0.5, edgecolor = "black")
plt.grid()

plt.title('City Latitude v. Cloudiness ')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("output_data/city_lat_cloudiness.png")

# %%
plt.scatter(city_df["lat"], city_df["wind speed"], alpha = 0.5, edgecolor = "black")
plt.grid()

plt.title('City Latitude v. Wind Speed (mph) ')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("output_data/city_lat_windspeed.png")

# %%
northernhem = city_df.loc[(city_df["lat"] >= 0)]

# %%
southernhem = city_df.loc[(city_df["lat"] <= 0)]

# %%
# Northern Hemisphere - Temperature (F) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = linregress (northernhem["lat"], northernhem["max temp"])

regression_values = (northernhem["lat"] * slope) + intercept 

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(northernhem["lat"], northernhem["max temp"])
plt.plot(northernhem["lat"], regression_values, "r-")
print(f"The r-squared is: {rvalue**2}")

plt.grid()

plt.title("Northern Hemisphere - Temperature(F) v. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq, (0, 20), fontsize = 15, color = "red")
# Out:
# The r-squared is: 0.7427487398997442

# %%
# Southern Hemisphere - Temperature (F) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = linregress (southernhem["lat"], southernhem["max temp"])

regression_values = (southernhem["lat"] * slope) + intercept

line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(southernhem["lat"], southernhem["max temp"])
plt.plot(southernhem["lat"], regression_values, "r-")
print(f"The r-squared is: {rvalue**2}")

plt.grid()

plt.title("Southern Hemisphere - Temperature (F) v. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.annotate(line_eq, (-50, 55), fontsize = 15, color = "red")
# Out:
# The r-squared is: 0.1207750110622039

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = linregress (northernhem["lat"], northernhem["humidity"])

regression_values = (northernhem["lat"] * slope) + intercept 

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(northernhem["lat"], northernhem["humidity"])
plt.plot(northernhem["lat"], regression_values, "r-")
print(f"The r-squared is: {rvalue**2}")

plt.grid()

plt.title("Northern Hemisphere - Humidity (%) v. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq, (40, 20), fontsize = 15, color = "red")
# Out:
# The r-squared is: 0.10295681101567278

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = linregress (southernhem["lat"], southernhem["humidity"])

regression_values = (southernhem["lat"] * slope) + intercept

line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(southernhem["lat"], southernhem["humidity"])
plt.plot(southernhem["lat"], regression_values, "r-")
print(f"The r-squared is: {rvalue**2}")

plt.grid()

plt.title("Southern Hemisphere - Humidity (%) v. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq, (-30, 40), fontsize = 15, color = "red")
# Out:
# The r-squared is: 0.11455194166088603

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = linregress (northernhem["lat"], northernhem["cloudiness"])

regression_values = (northernhem["lat"] * slope) + intercept 

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(northernhem["lat"], northernhem["cloudiness"])
plt.plot(northernhem["lat"], regression_values, "r-")
print(f"The r-squared is: {rvalue**2}")

plt.grid()

plt.title("Northern Hemisphere - Cloudiness (%) v. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.annotate(line_eq, (40, 40), fontsize = 15, color = "red")
# Out:
# The r-squared is: 0.12093340339701546

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = linregress (southernhem["lat"], southernhem["cloudiness"])

regression_values = (southernhem["lat"] * slope) + intercept

line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(southernhem["lat"], southernhem["cloudiness"])
plt.plot(southernhem["lat"], regression_values, "r-")
print(f"The r-squared is: {rvalue**2}")

plt.grid()

plt.title("Southern Hemisphere - Cloudiness (%) v. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq, (-50, 60), fontsize = 15, color = "red")
# Out:
# The r-squared is: 0.184457081442827

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = linregress (northernhem["lat"], northernhem["wind speed"])

regression_values = (northernhem["lat"] * slope) + intercept 

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(northernhem["lat"], northernhem["wind speed"])
plt.plot(northernhem["lat"], regression_values, "r-")
print(f"The r-squared is: {rvalue**2}")

plt.grid()

plt.title("Northern Hemisphere - Wind Speed (mph) v. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(line_eq, (10, 25), fontsize = 15, color = "red")
# Out:
# The r-squared is: 0.02538898877961698

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = linregress (southernhem["lat"], southernhem["wind speed"])

regression_values = (southernhem["lat"] * slope) + intercept

line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(southernhem["lat"], southernhem["wind speed"])
plt.plot(southernhem["lat"], regression_values, "r-")
print(f"The r-squared is: {rvalue**2}")

plt.grid()

plt.title("Southern Hemisphere - Wind Speed (mph) v. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(line_eq, (-32, 25), fontsize = 15, color = "red")
# Out:
# The r-squared is: 0.03572278352931864
